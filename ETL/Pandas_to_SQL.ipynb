# %%
# Import dependencies

import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# %%
from config import db_password

# %%
# Read in the cleaned country_vaccinations CSV file as Pandas DataFrames.
vaccination_table = pd.read_csv('../Resources/Cleaned_data/vaccination_table.csv', low_memory=False)
vaccination_table
# Out:
#      country_name  iso_code        date  total_vaccinations  \
# 0         Albania       ALB  2021-02-18              3049.0
# 1       Argentina       ARG  2021-01-21            265724.0
# 2       Argentina       ARG  2021-01-22            279602.0
# 3       Argentina       ARG  2021-01-23            288064.0
# 4       Argentina       ARG  2021-01-24            292023.0
# ...           ...       ...         ...                 ...
# 2512        Wales  OWID_WLS  2021-03-15           1412849.0
# 2513        Wales  OWID_WLS  2021-03-16           1446436.0
# 2514        Wales  OWID_WLS  2021-03-17           1484566.0
# 2515        Wales  OWID_WLS  2021-03-18           1523077.0
# 2516        Wales  OWID_WLS  2021-03-19           1561360.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                2438.0                    611.0                  1348.0
# 1              249372.0                  16352.0                 17791.0
# ...

# %%
# Create the connection string
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/Final_project"

# %%
# Cretae the Database Engine
engine = create_engine(db_string)

# %%
# Create table in SQL
# vaccination_table.to_sql(name='vaccination_table', con=engine, index = False)

# %%
# Read in the cleaned country_gdp CSV file as Pandas DataFrames.
country_master = pd.read_csv('../Resources/Cleaned_data/country_master.csv', low_memory=False)
country_master
# Out:
#      country_name  Population_2019 iso_code     indicator_name  \
# 0           Aruba           106314      ABW  GDP (current US$)
# 1     Afghanistan         38041754      AFG  GDP (current US$)
# 2          Angola         31825295      AGO  GDP (current US$)
# 3         Albania          2854191      ALB  GDP (current US$)
# 4         Andorra            77142      AND  GDP (current US$)
# ..            ...              ...      ...                ...
# 259        Kosovo          1794248      XKX  GDP (current US$)
# 260   Yemen, Rep.         29161922      YEM  GDP (current US$)
# 261  South Africa         58558270      ZAF  GDP (current US$)
# 262        Zambia         17861030      ZMB  GDP (current US$)
# 263      Zimbabwe         14645468      ZWE  GDP (current US$)
#
#      indicator_code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.CD  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
# Create the connection string
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/Final_project"

# %%
# Create the Database Engine
engine = create_engine(db_string)

# %%
# Create table in SQL
# country_master.to_sql(name='country_master', con=engine, index = False)

# %%
# Read in the cleaned human_dev_index CSV file as Pandas DataFrames.
human_dev_index = pd.read_csv('../Resources/Cleaned_data/human_dev_index.csv', low_memory=False)
human_dev_index
# Out:
#      HDI rank            country_name Human Development Type  \
# 0           1                  Norway              Very High
# 1           2                 Ireland              Very High
# 2           2             Switzerland              Very High
# 3           4  Hong Kong, China (SAR)              Very High
# 4           4                 Iceland              Very High
# ..        ...                     ...                    ...
# 190         0                  Monaco                  Other
# 191         0                   Nauru                  Other
# 192         0              San Marino                  Other
# 193         0                 Somalia                  Other
# 194         0                  Tuvalu                  Other
#
#      Human Development Index HDI 2019  Life expectancy at birth 2019  \
# 0                               0.957                          82.40
# 1                               0.955                          82.31
# ...

# %%
# Create the connection string
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/Final_project"

# %%
# Cretae the Database Engine
engine = create_engine(db_string)

# %%
# Create table in SQL
human_dev_index.to_sql(name='human_dev_index', con=engine, index = False)
