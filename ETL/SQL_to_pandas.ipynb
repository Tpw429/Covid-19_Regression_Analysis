# %%
# Import dependencies

import psycopg2
import pandas as pd
from sqlalchemy import create_engine
import seaborn as sns

# %%
from config import db_password

# %%
# Create the connection string
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/Final_project"

# %%
# Cretae the Database Engine
engine = create_engine(db_string)

# %%
# Connect to PostgreSQL server

dbConnection = engine.connect()

# %%
# Get data from Postgress database
gdp_vaccination_join = pd.read_sql("select * from gdp_vaccination_join", dbConnection);
gdp_vaccination_join
# Out:
#        country_name iso_code        date  total_vaccinations  \
# 0           Albania      ALB  2021-02-18              3049.0
# 1         Argentina      ARG  2021-01-21            265724.0
# 2         Argentina      ARG  2021-01-22            279602.0
# 3         Argentina      ARG  2021-01-23            288064.0
# 4         Argentina      ARG  2021-01-24            292023.0
# ...             ...      ...         ...                 ...
# 2243  United States      USA  2021-03-16         110737856.0
# 2244  United States      USA  2021-03-17         113037627.0
# 2245  United States      USA  2021-03-18         115730008.0
# 2246  United States      USA  2021-03-19         118313818.0
# 2247  United States      USA  2021-03-20         121441497.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                2438.0                    611.0                  1348.0
# 1              249372.0                  16352.0                 17791.0
# ...

# %%
# Save file to csv
# gdp_vaccination_join = gdp_vaccination_join.to_csv('../Resources/Cleaned_data/gdp_vaccination_join.csv',index =False)

# %%
# Get data from Postgress database
gdp_vaccination_hdi = pd.read_sql("select * from gdp_vaccination_hdi", dbConnection);
gdp_vaccination_hdi
# Out:
#      country_name iso_code        date  total_vaccinations  people_vaccinated  \
# 0          Norway      NOR  2021-03-18            758514.0           497011.0
# 1          Norway      NOR  2021-03-17            737667.0           477442.0
# 2          Norway      NOR  2021-03-16            713415.0           454675.0
# 3          Norway      NOR  2021-03-15            707189.0           449054.0
# 4          Norway      NOR  2021-03-14            706669.0           448952.0
# ...           ...      ...         ...                 ...                ...
# 2000        India      IND  2021-02-17           9186757.0          8844641.0
# 2001        India      IND  2021-02-16           8857341.0          8641002.0
# 2002        India      IND  2021-02-13           8052454.0          8044786.0
# 2003   San Marino      SMR  2021-03-19              7923.0             7888.0
# 2004   San Marino      SMR  2021-03-18              7328.0             7299.0
#
# ...

# %%
sns.pairplot(gdp_vaccination_hdi[['total_vaccinations','people_vaccinated','people_fully_vaccinated','total_vaccinations_per_hundred','GDP_2019','Population_2019','HDI rank',]])

# %%
# Save file to csv
# gdp_vaccination_hdi = gdp_vaccination_hdi.to_csv('../Resources/Cleaned_data/gdp_vaccination_hdi.csv',index =False)

# %%
# Get data from Postgress database
country_group = pd.read_sql("select * from country_group", dbConnection);
country_group
# Out:
#             country_name iso_code  population_2019  people_fully_vaccinated  \
# 0                Morocco      MAR         36471769             1.427594e+07
# 1                 Israel      ISR          9053300             1.721946e+08
# 2                Hungary      HUN          9769949             1.158358e+07
# 3                Austria      AUT          8877067             9.744762e+06
# 4           South Africa      ZAF         58558270             2.464155e+06
# 5                 Greece      GRC         10716322             9.937428e+06
# 6         United Kingdom      GBR         66834405             5.267752e+07
# 7                Denmark      DNK          5818553             9.302367e+06
# 8                Romania      ROU         19356544             2.491800e+07
# 9                 Turkey      TUR         83429615             7.698843e+07
# 10               Iceland      ISL           361313             1.232140e+05
# ...

# %%
# Save file to csv
# country_group = country_group.to_csv('../Resources/Cleaned_data/country_group.csv',index =False)
